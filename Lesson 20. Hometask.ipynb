# %% [markdown]
# ### Завдання 1. Побудувати таблицю за допомогою Markdown.

# %% [markdown]
# -------------------------
# |  **Name**   | **Last Name** |      **Job**          | **Salary** |     **Company**    |
# |    :---:    |     :---:     |       :---:           |    :---:   |        :---:       |
# | *Volodymyr* | *Zelenskyy*   | Ukraine President     |  15 000    | Ukrainian citizens |
# | *Boris*     | *Johnson*     | Former UK PM          |  30 000    | British citizens   |
# | *Joe*       | *Biden*       | USA President         |  40 000    | Americans citizens |
# | *Andrzej*   | *Duda*        | Poland President      |  25 000    | Poland citizens    |
# | *Olaf*      | *Scholz*      | Chancellor of Germany |  35 000    | German citizens    |

# %% [markdown]
# ### Завдання 2. Додати код і обчислити за допомогою "магічної" команди %%timeit середній час роботи.

# %%
# %%timeit
import numpy as np
import random

int_list = []
float_list = []


def get_sorting(): 
    
    for i in np.arange(0, 50):           
        int_list.append(random.randint(0, 1000))
    print('Integer list:', int_list)
    print('In the integer list', len(int_list), 'random integer numbers.')    
         
   
    for i in np.arange(0, 50):
        float_list.append(random.uniform(0.1, 100.0))
    print('\nFloat list:', float_list)
    print('In the flot list', len(float_list), 'random float numbers.')       
    
    
get_sorting()
# Out:
# Integer list: [887, 950, 663, 630, 639, 930, 790, 954, 76, 15, 328, 768, 358, 507, 723, 763, 954, 794, 901, 40, 916, 453, 230, 288, 511, 531, 409, 263, 449, 580, 622, 19, 105, 180, 778, 383, 691, 722, 969, 401, 843, 228, 28, 701, 29, 880, 901, 952, 781, 711]
# In the integer list 50 random integer numbers.
#
# ...
